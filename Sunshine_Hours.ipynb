# %%
import pandas as pd

# %% [markdown]
# ## Do the ETL process on the Sunshine Hours

# %%
# Load the Sunshine hours for cities in the world excel file
sunshine_hours_df = pd.read_csv("Resources/Sunshine hours for cities in the world.csv")
sunshine_hours_df.head()
# Out:
#        Country     City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0  Ivory Coast   Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1  Ivory Coast   Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2  Ivory Coast  Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3  Ivory Coast  Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4  Ivory Coast    Ferké  279.0  249.0  253.0  229.0  251.0  221.0  183.0
#
#      Aug    Sep    Oct    Nov    Dec    Year
# 0   80.0  110.0  155.0  171.0  164.0  1823.0
# 1   82.0  115.0  170.0  191.0  198.0  2092.0
# 2  125.0  139.0  215.0  224.0  224.0  2296.0
# 3  174.5  185.4  235.8  252.0  242.6  2638.6
# 4  151.0  173.0  245.0  261.0  262.0  2757.0

# %%
# Load the World cities in the world excel file
world_cities_df = pd.read_csv("Resources/worldcities.csv")
world_cities_df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37732000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
# From the world_cities_df select the needed columns
world_cities_df = world_cities_df[["country", "city_ascii", "lat", "lng"]]
world_cities_df
# Out:
#                    country        city_ascii      lat       lng
# 0                    Japan             Tokyo  35.6897  139.6922
# 1                Indonesia           Jakarta  -6.1750  106.8275
# 2                    India             Delhi  28.6100   77.2300
# 3                    China         Guangzhou  23.1300  113.2600
# 4                    India            Mumbai  19.0761   72.8775
# ...                    ...               ...      ...       ...
# 47863         Korea, North        Munha-dong  39.3813  127.2517
# 47864         Korea, North            Sil-li  39.4880  125.4640
# 47865         Korea, South              Muan  34.9897  126.4714
# 47866         Korea, South         Hongseong  36.6009  126.6650
# 47867  U.S. Virgin Islands  Charlotte Amalie  18.3420  -64.9331
#
# [47868 rows x 4 columns]

# %%
# Merge the two DataFrames
tableau_mapping_df = pd.merge(sunshine_hours_df, world_cities_df, left_on=["Country", "City"], right_on=["country", "city_ascii"], how="left")
tableau_mapping_df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4    Ivory Coast       Ferké  279.0  249.0  253.0  229.0  251.0  221.0  183.0
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 411  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 412  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 413  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 414         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 415  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
# Filter by NaN on the "country" to find countries with spelling mismatch
nan_country = tableau_mapping_df.loc[tableau_mapping_df["country"].isna(), :]
nan_country
# Out:
#               Country           City    Jan    Feb    Mar    Apr    May  \
# 0         Ivory Coast         Gagnoa  183.0  180.0  196.0  188.0  181.0
# 1         Ivory Coast         Bouaké  242.0  224.0  219.0  194.0  208.0
# 2         Ivory Coast        Abidjan  223.0  223.0  239.0  214.0  205.0
# 3         Ivory Coast        Odienné  242.0  220.2  217.3  214.7  248.8
# 4         Ivory Coast          Ferké  279.0  249.0  253.0  229.0  251.0
# ..                ...            ...    ...    ...    ...    ...    ...
# 380          Colombia       Medellín  175.5  149.0  154.2  127.9  138.9
# 383  Falkland Islands        Stanley  198.0  161.0  169.0  115.0   77.0
# 386          Paraguay       Asunción  276.0  246.0  254.0  228.0  205.0
# 393         Australia  Tennant Creek  285.2  257.1  285.2  294.0  300.7
# 394         Australia     Oodnadatta  337.9  315.0  313.1  273.0  244.9
#
#        Jun    Jul    Aug    Sep    Oct    Nov    Dec    Year country  \
# ...

# %%
# Replace the country on the world_cities_df
world_cities_df['country'] = world_cities_df['country'].replace("Côte d’Ivoire", "Ivory Coast")
world_cities_df['country'] = world_cities_df['country'].replace("Gambia, The", "Gambia")
world_cities_df['country'] = world_cities_df['country'].replace("Congo (Brazzaville)", "Congo")
world_cities_df['country'] = world_cities_df['country'].replace("Congo (Kinshasa)", "Democratic Republic of the Congo")
world_cities_df['country'] = world_cities_df['country'].replace("Hong Kong", "China")
world_cities_df['country'] = world_cities_df['country'].replace("Macau", "China")
world_cities_df['country'] = world_cities_df['country'].replace("Korea, North", "North Korea")
world_cities_df['country'] = world_cities_df['country'].replace("Korea, South", "South Korea")
world_cities_df['country'] = world_cities_df['country'].replace("United Arab Emirates", "United ArabEmirates")
world_cities_df['country'] = world_cities_df['country'].replace("Czechia", "Czech Republic")
world_cities_df['country'] = world_cities_df['country'].replace("Saint Pierre and Miquelon", "Saint Pierreand Miquelon")
world_cities_df['country'] = world_cities_df['country'].replace("Falkland Islands (Islas Malvinas)", "Falkland Islands")

# %%
# Replace the city on the world_cities_df or the sunshine_hours_df
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Sansanne-Mango", "Mango")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Bouake", "Bouaké")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Odienne", "Odienné")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Lome", "Lomé")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Ngaoundere", "N'Gaoundéré")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Yaounde", "Yaoundé")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Abeche", "Abéché")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Thies", "Thiès")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Djibouti", "Ségou")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Dar es Salaam", "Dar-es-Salaam")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Mekele", "Mekelle")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Addis Ababa", "Addis Abeba")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Urumqi", "Ürümqi")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Bandar `Abbas", "Bandar Abbas")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Tel Aviv-Yafo", "Tel Aviv")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Petropavlovsk-Kamchatskiy", "Petropavlovsk-Kamchatsky")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Ronne", "Rønne")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Viljandi", "Vilsandi")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Torshavn", "Tórshavn")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Luxembourg", "Luxembourg City")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Chisinau", "Chișinău")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Tromso", "Tromsø")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Nis", "Niš")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Almeria", "Almería")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Cadiz", "Cádiz")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Seville", "Sevilla")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("New York", "New York City")
sunshine_hours_df['City'] = sunshine_hours_df['City'].replace("OklahomaCity", "Oklahoma City")
sunshine_hours_df['City'] = sunshine_hours_df['City'].replace("Portland (OR)", "Portland")
sunshine_hours_df['City'] = sunshine_hours_df['City'].replace("Richmond (VA)", "Richmond")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Washington", "Washington,D.C.")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Cordoba", "Córdoba")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Belem", "Belém")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Brasilia", "Brasília")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Sao Paulo", "São Paulo")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Concepcion", "Concepción")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Bogota", "Bogotá")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Medellin", "Medellín")
world_cities_df['city_ascii'] = world_cities_df['city_ascii'].replace("Asuncion", "Asunción")

# %%
# Remerge the two DataFrames
tableau_mapping_df = pd.merge(sunshine_hours_df, world_cities_df, left_on=["Country", "City"], right_on=["country", "city_ascii"], how="left")
tableau_mapping_df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4    Ivory Coast       Ferké  279.0  249.0  253.0  229.0  251.0  221.0  183.0
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 429  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 430  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 431  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 432         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 433  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
# Drop the NaN on the target column "Healthy life expectancy at birth"
tableau_mapping_df = tableau_mapping_df.dropna(subset = ["country"])
tableau_mapping_df.head()
# Out:
#        Country     City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0  Ivory Coast   Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1  Ivory Coast   Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2  Ivory Coast  Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3  Ivory Coast  Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 5        Benin  Cotonou  213.9  210.0  223.2  219.0  213.9  141.0  136.4
#
#      Aug    Sep    Oct    Nov    Dec    Year      country city_ascii     lat  \
# 0   80.0  110.0  155.0  171.0  164.0  1823.0  Ivory Coast     Gagnoa  6.1333
# 1   82.0  115.0  170.0  191.0  198.0  2092.0  Ivory Coast     Bouaké  7.6833
# 2  125.0  139.0  215.0  224.0  224.0  2296.0  Ivory Coast    Abidjan  5.3167
# 3  174.5  185.4  235.8  252.0  242.6  2638.6  Ivory Coast    Odienné  9.5000
# 5  148.8  165.0  207.7  243.0  223.2  2345.2        Benin    Cotonou  6.3667
#
#       lng
# 0 -5.9333
# 1 -5.0167
# 2 -4.0333
# 3 -7.5667
# ...

# %%
# Drop "country" and "city_ascii" columns
tableau_mapping_df = tableau_mapping_df.drop(columns=["country", "city_ascii"])
tableau_mapping_df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 5          Benin     Cotonou  213.9  210.0  223.2  219.0  213.9  141.0  136.4
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 429  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 430  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 431  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 432         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 433  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
# Load the cvs file for Country Regions
country_regions_df = pd.read_csv("Resources/Countries and regions.csv")
country_regions_df.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
# Keep the needed columns
country_regions_df = country_regions_df.drop(columns=["alpha-2", "alpha-3", "country-code", "iso_3166-2", "intermediate-region", "region-code", "sub-region-code", "intermediate-region-code"])
country_regions_df.tail(25)
# Out:
#                                                   name    region  \
# 224                                              Tonga   Oceania
# 225                                Trinidad and Tobago  Americas
# 226                                            Tunisia    Africa
# 227                                            Türkiye      Asia
# 228                                       Turkmenistan      Asia
# 229                           Turks and Caicos Islands  Americas
# 230                                             Tuvalu   Oceania
# 231                                             Uganda    Africa
# 232                                            Ukraine    Europe
# 233                               United Arab Emirates      Asia
# 234  United Kingdom of Great Britain and Northern I...    Europe
# 235                           United States of America  Americas
# 236               United States Minor Outlying Islands   Oceania
# ...

# %%
# Merge the tableau_mapping_df with the country_regions_df
region_merge_df = pd.merge(tableau_mapping_df, country_regions_df, left_on="Country", right_on="name", how="left")
region_merge_df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4          Benin     Cotonou  213.9  210.0  223.2  219.0  213.9  141.0  136.4
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 415  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 416  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 417  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 418         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 419  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
# Filter by NaN on the "Country" to find countries with spelling mismatch
nan = region_merge_df.loc[region_merge_df["name"].isna(), :]
print(f'Unique NaN Country: {nan["Country"].unique()}')
# Out:
# Unique NaN Country: ['Tanzania' 'Democratic Republic of the Congo' 'Iran' 'North Korea'
#  'Russia' 'South Korea' 'Taiwan' 'Turkey' 'United ArabEmirates'
#  'Czech Republic' 'Moldova' 'Netherlands' 'United Kingdom'
#  'Saint Pierreand Miquelon' 'United States' 'Bolivia' 'Falkland Islands'
#  'Venezuela']

# %%
# Replace the country on the tableau_mapping_df
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Tanzania', 'Tanzania, United Republic of')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Democratic Republic of the Congo', 'Congo, Democratic Republic of the')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Iran', 'Iran, Islamic Republic of')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('North Korea', "Korea, Democratic People's Republic of")
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Russia', 'Russian Federation')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('South Korea', 'Korea, Republic of')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Taiwan', 'Taiwan, Province of China')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('United ArabEmirates', 'United Arab Emirates')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Moldova', 'Moldova, Republic of')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Netherlands', 'Netherlands, Kingdom of the')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('United Kingdom', 'United Kingdom of Great Britain and Northern Ireland')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Saint Pierreand Miquelon', 'Saint Pierre and Miquelon')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('United States', 'United States of America')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Bolivia', 'Bolivia, Plurinational State of')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Falkland Islands', 'Falkland Islands (Malvinas)')
tableau_mapping_df['Country'] = tableau_mapping_df['Country'].replace('Venezuela', 'Venezuela, Bolivarian Republic of')

# %%
# Replace the name on the country_regions_df
country_regions_df['name'] = country_regions_df['name'].replace('Türkiye', 'Turkey')
country_regions_df['name'] = country_regions_df['name'].replace('Czechia', 'Czech Republic')

# %%
# Update the data for Taiwan, Province of China
country_regions_df.loc[country_regions_df['name'] == 'Taiwan, Province of China', "region"] = 'Asia'
country_regions_df.loc[country_regions_df['name'] == 'Taiwan, Province of China', "sub-region"] = 'Eastern Asia'

# %%
# Re-merge the tableau_mapping_df with the country_regions_df
tableau_mapping_df = pd.merge(tableau_mapping_df, country_regions_df, left_on="Country", right_on="name", how="left")
tableau_mapping_df
# Out:
#          Country        City    Jan    Feb    Mar    Apr    May    Jun    Jul  \
# 0    Ivory Coast      Gagnoa  183.0  180.0  196.0  188.0  181.0  118.0   97.0
# 1    Ivory Coast      Bouaké  242.0  224.0  219.0  194.0  208.0  145.0  104.0
# 2    Ivory Coast     Abidjan  223.0  223.0  239.0  214.0  205.0  128.0  137.0
# 3    Ivory Coast     Odienné  242.0  220.2  217.3  214.7  248.8  221.8  183.5
# 4          Benin     Cotonou  213.9  210.0  223.2  219.0  213.9  141.0  136.4
# ..           ...         ...    ...    ...    ...    ...    ...    ...    ...
# 415  New Zealand  Wellington  240.3  205.0  194.7  153.8  126.0  102.3  111.4
# 416  New Zealand    Hamilton  229.8  192.9  193.3  165.1  138.3  112.8  126.4
# 417  New Zealand    Auckland  228.8  194.9  189.2  157.3  139.8  110.3  128.1
# 418         Fiji        Suva  192.2  178.0  170.5  153.0  145.7  141.0  136.4
# 419  New Zealand     Dunedin  179.6  158.0  146.1  125.9  108.4   95.3  110.6
#
# ...

# %%
# Confirm there aren't any NaN on the "Country" to find countries with spelling mismatch
nan1 = tableau_mapping_df.loc[tableau_mapping_df["name"].isna(), :]
print(f'Unique NaN Country: {nan1["Country"].unique()}')
# Out:
# Unique NaN Country: []

# %%
# Drop name column
tableau_mapping_df = tableau_mapping_df.drop(columns="name")

# %%
tableau_mapping_df.columns
# Out:
# Index(['Country', 'City', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Year', 'lat', 'lng', 'region',
#        'sub-region'],
#       dtype='object')

# %%
# Reorganize the order of the columns
tableau_mapping_df = tableau_mapping_df[['region', 'sub-region', 'Country', 'City', 'lat', 'lng', 'Jan', 'Feb', 
                                         'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Year']]
tableau_mapping_df
# Out:
#       region                 sub-region      Country        City      lat  \
# 0     Africa         Sub-Saharan Africa  Ivory Coast      Gagnoa   6.1333
# 1     Africa         Sub-Saharan Africa  Ivory Coast      Bouaké   7.6833
# 2     Africa         Sub-Saharan Africa  Ivory Coast     Abidjan   5.3167
# 3     Africa         Sub-Saharan Africa  Ivory Coast     Odienné   9.5000
# 4     Africa         Sub-Saharan Africa        Benin     Cotonou   6.3667
# ..       ...                        ...          ...         ...      ...
# 415  Oceania  Australia and New Zealand  New Zealand  Wellington -41.2889
# 416  Oceania  Australia and New Zealand  New Zealand    Hamilton -37.7833
# 417  Oceania  Australia and New Zealand  New Zealand    Auckland -36.8406
# 418  Oceania                  Melanesia         Fiji        Suva -18.1416
# 419  Oceania  Australia and New Zealand  New Zealand     Dunedin -45.8742
#
#           lng    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# ...

# %%
# Write CSV file of the dataset
tableau_mapping_df.to_csv("Datasets_ML/Tableau_Mapping.csv", index=False, header=True)
