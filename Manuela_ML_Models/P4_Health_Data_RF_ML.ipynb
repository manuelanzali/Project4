# %%
#import dependencies

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#Use to allow colab access to GoogleDrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob

# Search for the file across all of MyDrive
file_path = glob.glob('/content/drive/MyDrive/**/*World_Health_Data.xlsx', recursive=True)
print(file_path)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/Project4/World_Health_Data.xlsx']

# %%
import pandas as pd
import os

#Replace Folder Name with actual folder name
file_path = '/content/drive/MyDrive/Colab Notebooks/Project4/World_Health_Data.xlsx'



#Read the excel file
world_health_df = pd.read_excel(file_path)

world_health_df.head()
# Out:
#                                             IND_NAME DIM_GEO_NAME  \
# 0             Adolescent birth rate (per 1000 women)  Afghanistan
# 1             Adolescent birth rate (per 1000 women)  Afghanistan
# 2  Age-standardized mortality rate attributed to ...  Afghanistan
# 3  Age-standardized prevalence of hypertension am...  Afghanistan
# 4  Age-standardized prevalence of obesity among a...  Afghanistan
#
#                IND_CODE DIM_GEO_CODE  DIM_TIME_YEAR           DIM_1_CODE  \
# 0        MDG_0000000003          AFG           2021  AGEGROUP_YEARS15-19
# 1        MDG_0000000003          AFG           2021  AGEGROUP_YEARS10-14
# 2            SDGAIRBODA          AFG           2019             SEX_BTSX
# 3  NCD_HYP_PREVALENCE_A          AFG           2019             SEX_BTSX
# 4           NCD_BMI_30A          AFG           2022             SEX_BTSX
#
#    VALUE_NUMERIC VALUE_STRING  \
# 0      62.000000         62.0
# 1      18.000000         18.0
# 2     265.664520        265.7
# 3      40.200001         40.2
# 4      19.222589         19.2
#
#                                       VALUE_COMMENTS
# 0  Afghanistan 2022-2023 Multiple Indicator Clust...
# 1  Afghanistan 2022-2023 Multiple Indicator Clust...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Use ETL to begin cleaning the data

#Get list of column names
world_health_df.columns.tolist()
# Out:
# ['IND_NAME',
#  'DIM_GEO_NAME',
#  'IND_CODE',
#  'DIM_GEO_CODE',
#  'DIM_TIME_YEAR',
#  'DIM_1_CODE',
#  'VALUE_NUMERIC',
#  'VALUE_STRING',
#  'VALUE_COMMENTS']

# %%
#Rename some of the columns to make it easier to read

world_health_df = world_health_df.rename(columns={"IND_NAME": "Health Indicator Name",
                                "DIM_GEO_NAME": "Country",
                                "IND_CODE": "Health Indicator Code",
                                "DIM_GEO_CODE": "Country Code",
                                "DIM_TIME_YEAR": "Year",
                                "DIM_1_CODE": "Demographic",
                                "VALUE_NUMERIC": "Health Indicator Value",
                                "VALUE_STRING": "Rounded Indicator Value",
                                "VALUE_COMMENTS": "Data Source"})
world_health_df.head()
# Out:
#                                Health Indicator Name      Country  \
# 0             Adolescent birth rate (per 1000 women)  Afghanistan
# 1             Adolescent birth rate (per 1000 women)  Afghanistan
# 2  Age-standardized mortality rate attributed to ...  Afghanistan
# 3  Age-standardized prevalence of hypertension am...  Afghanistan
# 4  Age-standardized prevalence of obesity among a...  Afghanistan
#
#   Health Indicator Code Country Code  Year          Demographic  \
# 0        MDG_0000000003          AFG  2021  AGEGROUP_YEARS15-19
# 1        MDG_0000000003          AFG  2021  AGEGROUP_YEARS10-14
# 2            SDGAIRBODA          AFG  2019             SEX_BTSX
# 3  NCD_HYP_PREVALENCE_A          AFG  2019             SEX_BTSX
# 4           NCD_BMI_30A          AFG  2022             SEX_BTSX
#
#    Health Indicator Value Rounded Indicator Value  \
# 0               62.000000                    62.0
# 1               18.000000                    18.0
# 2              265.664520                   265.7
# 3               40.200001                    40.2
# 4               19.222589                    19.2
#
#                                          Data Source
# 0  Afghanistan 2022-2023 Multiple Indicator Clust...
# 1  Afghanistan 2022-2023 Multiple Indicator Clust...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#See what kind of datatype is in each column
world_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Health Indicator Name    10503 non-null  object
#  1   Country                  10503 non-null  object
#  2   Health Indicator Code    10503 non-null  object
#  3   Country Code             10503 non-null  object
#  4   Year                     10503 non-null  int64
#  5   Demographic              3863 non-null   object
#  6   Health Indicator Value   10503 non-null  float64
#  7   Rounded Indicator Value  10503 non-null  object
#  8   Data Source              1847 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 738.6+ KB

# %%
#Look for missing values
world_health_df.count()
# Out:
# Health Indicator Name      10503
# Country                    10503
# Health Indicator Code      10503
# Country Code               10503
# Year                       10503
# Demographic                 3863
# Health Indicator Value     10503
# Rounded Indicator Value    10503
# Data Source                 1847
# dtype: int64

# %%
#Reorder Columns
world_health_df = world_health_df[['Year','Country','Country Code','Health Indicator Name','Health Indicator Code',	'Health Indicator Value','Rounded Indicator Value','Demographic',	'Data Source']]
world_health_df.head()
# Out:
#    Year      Country Country Code  \
# 0  2021  Afghanistan          AFG
# 1  2021  Afghanistan          AFG
# 2  2019  Afghanistan          AFG
# 3  2019  Afghanistan          AFG
# 4  2022  Afghanistan          AFG
#
#                                Health Indicator Name Health Indicator Code  \
# 0             Adolescent birth rate (per 1000 women)        MDG_0000000003
# 1             Adolescent birth rate (per 1000 women)        MDG_0000000003
# 2  Age-standardized mortality rate attributed to ...            SDGAIRBODA
# 3  Age-standardized prevalence of hypertension am...  NCD_HYP_PREVALENCE_A
# 4  Age-standardized prevalence of obesity among a...           NCD_BMI_30A
#
#    Health Indicator Value Rounded Indicator Value          Demographic  \
# 0               62.000000                    62.0  AGEGROUP_YEARS15-19
# 1               18.000000                    18.0  AGEGROUP_YEARS10-14
# 2              265.664520                   265.7             SEX_BTSX
# 3               40.200001                    40.2             SEX_BTSX
# 4               19.222589                    19.2             SEX_BTSX
#
#                                          Data Source
# 0  Afghanistan 2022-2023 Multiple Indicator Clust...
# 1  Afghanistan 2022-2023 Multiple Indicator Clust...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Drop the Health Indicator Code, Rounded Indicator Value and Data Source Columns
cleaned_health_df = world_health_df.drop(["Health Indicator Code", "Rounded Indicator Value", "Data Source"], axis=1)
cleaned_health_df.head()
# Out:
#    Year      Country Country Code  \
# 0  2021  Afghanistan          AFG
# 1  2021  Afghanistan          AFG
# 2  2019  Afghanistan          AFG
# 3  2019  Afghanistan          AFG
# 4  2022  Afghanistan          AFG
#
#                                Health Indicator Name  Health Indicator Value  \
# 0             Adolescent birth rate (per 1000 women)               62.000000
# 1             Adolescent birth rate (per 1000 women)               18.000000
# 2  Age-standardized mortality rate attributed to ...              265.664520
# 3  Age-standardized prevalence of hypertension am...               40.200001
# 4  Age-standardized prevalence of obesity among a...               19.222589
#
#            Demographic
# 0  AGEGROUP_YEARS15-19
# 1  AGEGROUP_YEARS10-14
# 2             SEX_BTSX
# 3             SEX_BTSX
# 4             SEX_BTSX

# %%
#Begin with Random Forest Model
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline

# Define features set, Want to predict the overall happiness, (X) Target: Life ladder (happiness), Features are all other columns

X = cleaned_health_df.copy()
X.drop("Health Indicator Value", axis=1, inplace=True)
X.head()
# Out:
#    Year      Country Country Code  \
# 0  2021  Afghanistan          AFG
# 1  2021  Afghanistan          AFG
# 2  2019  Afghanistan          AFG
# 3  2019  Afghanistan          AFG
# 4  2022  Afghanistan          AFG
#
#                                Health Indicator Name          Demographic
# 0             Adolescent birth rate (per 1000 women)  AGEGROUP_YEARS15-19
# 1             Adolescent birth rate (per 1000 women)  AGEGROUP_YEARS10-14
# 2  Age-standardized mortality rate attributed to ...             SEX_BTSX
# 3  Age-standardized prevalence of hypertension am...             SEX_BTSX
# 4  Age-standardized prevalence of obesity among a...             SEX_BTSX

# %%
# Define target vector
y = cleaned_health_df["Health Indicator Value"].ravel()
y[:5]
# Out:
# <ipython-input-14-09700826b0a4>:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y = cleaned_health_df["Health Indicator Value"].ravel()
# array([ 62.        ,  18.        , 265.66452026,  40.20000076,
#         19.22258949])

# %%
#Encode the categorical variables using get_dummies

X = pd.get_dummies((cleaned_health_df[['Country', 'Country Code', 'Health Indicator Name',	'Demographic']]))
X
# Out:
#        Country_Afghanistan  Country_African Region  Country_Albania  \
# 0                     True                   False            False
# 1                     True                   False            False
# 2                     True                   False            False
# 3                     True                   False            False
# 4                     True                   False            False
# ...                    ...                     ...              ...
# 10498                False                   False            False
# 10499                False                   False            False
# 10500                False                   False            False
# 10501                False                   False            False
# 10502                False                   False            False
#
#        Country_Algeria  Country_Andorra  Country_Angola  \
# 0                False            False           False
# 1                False            False           False
# 2                False            False           False
# 3                False            False           False
# 4                False            False           False
# ...                ...              ...             ...
# 10498            False            False           False
# 10499            False            False           False
# 10500            False            False           False
# 10501            False            False           False
# 10502            False            False           False
#
#        Country_Antigua and Barbuda  Country_Argentina  Country_Armenia  \
# 0                            False              False            False
# 1                            False              False            False
# 2                            False              False            False
# 3                            False              False            False
# 4                            False              False            False
# ...                            ...                ...              ...
# 10498                        False              False            False
# 10499                        False              False            False
# 10500                        False              False            False
# 10501                        False              False            False
# 10502                        False              False            False
#
#        Country_Australia  ...  \
# 0                  False  ...
# 1                  False  ...
# 2                  False  ...
# 3                  False  ...
# 4                  False  ...
# ...                  ...  ...
# 10498              False  ...
# 10499              False  ...
# 10500              False  ...
# 10501              False  ...
# 10502              False  ...
#
#        Health Indicator Name_Tuberculosis incidence (per 100 000 population)  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 10498                                              False
# 10499                                              False
# 10500                                               True
# 10501                                              False
# 10502                                              False
#
#        Health Indicator Name_UHC: Service coverage index  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 10498                                              False
# 10499                                              False
# 10500                                              False
# 10501                                               True
# 10502                                              False
#
#        Health Indicator Name_Under-five mortality rate (per 1000 live births)  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 10498                                              False
# 10499                                              False
# 10500                                              False
# 10501                                              False
# 10502                                               True
#
#        Demographic_AGEGROUP_YEARS10-14  Demographic_AGEGROUP_YEARS15-19  \
# 0                                False                             True
# 1                                 True                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 10498                            False                            False
# 10499                            False                            False
# 10500                            False                            False
# 10501                            False                            False
# 10502                            False                            False
#
#        Demographic_ALCOHOL  Demographic_DRUG  Demographic_SEX_BTSX  \
# 0                    False             False                 False
# 1                    False             False                 False
# 2                    False             False                  True
# 3                    False             False                  True
# 4                    False             False                  True
# ...                    ...               ...                   ...
# 10498                False             False                  True
# 10499                False             False                 False
# 10500                False             False                 False
# 10501                False             False                 False
# 10502                False             False                  True
#
#        Demographic_SEX_FMLE  Demographic_SEX_MLE
# 0                     False                False
# 1                     False                False
# 2                     False                False
# 3                     False                False
# 4                     False                False
# ...                     ...                  ...
# 10498                 False                False
# 10499                 False                False
# 10500                 False                False
# 10501                 False                False
# 10502                 False                False
#
# [10503 rows x 476 columns]

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Fit the Random Forest Model

# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-cc942b782432> in <cell line: 7>()
#       5
#       6 # Fitting the model
# ----> 7 rf_model = rf_model.fit(X_train_scaled, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     419         self._n_samples, self.n_outputs_ = y.shape
#     420
# --> 421         y, expanded_class_weight = self._validate_y_class_weight(y)
#     422
#     423         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
#     829
#     830     def _validate_y_class_weight(self, y):
# --> 831         check_classification_targets(y)
#     832
#     833         y = np.copy(y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     217         "multilabel-sequences",
#     218     ]:
# --> 219         raise ValueError(
#     220             f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     221             "classifier, which expects discrete classes on a "
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
